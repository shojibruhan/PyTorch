# %% [markdown]
# <a href="https://colab.research.google.com/github/shojibruhan/PyTorch/blob/main/pytorch_fundamental.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
print(torch.__version__)
# Out:
# 2.10.0+cpu
